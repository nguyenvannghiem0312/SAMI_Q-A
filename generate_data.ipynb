# %%
import os
import openai
import time
import pandas as pd
from datasets import load_dataset
from tqdm import tqdm
import json

# %%
meta_corpus = load_dataset(
    "json",
    # data_files="data/corpus_chunks.jsonl",
    data_files="documents_chunk/documents_chunk_hand.jsonl",
    split="train"
).to_list()
# Out:
# Found cached dataset json (C:/Users/PC/.cache/huggingface/datasets/json/default-0cd705c3c0be7317/0.0.0/fe5dd6ea2639a6df622901539cb550cf8797e5a6b2dd7af1cf934bed8e233e6e)

# %%
prompt = """Tôi cung cấp cho bạn 1 đoạn văn. Bạn chỉ cần đưa ra 5 câu hỏi cho đoạn văn và câu trả lời cho câu hỏi đó. Bạn bắt buộc phải trả về theo format là 1 JSON:
{
"question": [Q1, Q2, Q3, Q4, Q5],
"answer": [AS1, AS2, AS3, AS4, AS5]
}
"""

# %%
OPEN_API_KEY = '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'
model_name = "gpt-3.5-turbo-instruct"

# %%
def get_response(user_request, max_len, temp):
    """
        Get a response from the OpenAI API based on the given arguments.

        Args:
            args (object): The arguments object containing the model name, user request, maximum length, and temperature.
            user_request (str): The user's request to be used as the prompt for generating a response.
            max_len (int): The maximum number of tokens in the generated response.
            temp (float): The temperature parameter for controlling the randomness of the generated response.

        Returns:
            object: The response generated by the OpenAI API.
    """
    responese = openai.Completion.create(
        engine = model_name,
        prompt = user_request,
        max_tokens = max_len,
        n = 1,
        temperature = temp
    )

    return responese

# %%
generate_data = []

# %%
openai.api_key = OPEN_API_KEY

# %%
for corpus in meta_corpus:
    input = prompt + "\n\n" + corpus['chunk']
    response =get_response(input, 1024, 0)
    # print(response['choices'][0]['text'])
    result = json.loads(response['choices'][0]['text'])
    generate_data.append(result)

# %%
pd.DataFrame(generate_data).to_json("generate_data.json", orient='records', force_ascii=False)

# %%
with open('documents_chunk/', "w+", encoding="utf8") as outfile:
        # for chunk in self.meta_corpus:
        #     d = json.dumps(chunk, ensure_ascii=False) + "\n"
        #     outfile.write(d)
        print('run')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 with open('documents_chunk/', "w+", encoding="utf8") as outfile:
#       2         # for chunk in self.meta_corpus:
#       3         #     d = json.dumps(chunk, ensure_ascii=False) + "\n"
#       4         #     outfile.write(d)
#       5         print('run')
#
# File c:\Users\PC\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: 'documents_chunk/'

# %%
list_numbers = [1, 2, 3, 4, 5]
number = 2

# Chia mỗi phần tử của list cho số 2
divided_list = list(map(lambda x: x / number, list_numbers))

print(divided_list)
# Out:
# [0.5, 1.0, 1.5, 2.0, 2.5]
